# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ***Library --> module --> Functions ***

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Bhevendra/ML-Datasets/main/retail_data/customers.csv")

# %% [markdown]
# - import
# - session creation
# - data frame creation
# -    -> data frame
# -    -> data write
# - delta format
# -    -> mode

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

spark_df = spark.createDataFrame(df)

spark_df.write.format("delta").mode("overwrite").saveAsTable("batch_2.data.customers")
